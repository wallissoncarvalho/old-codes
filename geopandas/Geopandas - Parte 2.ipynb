# %%
# %matplotlib inline
import pandas as pd
import geopandas as gpd
import os
import zipfile
import shutil

# %% [markdown]
# ## Tratamento dos dados

# %%
#Criar um diretório caso ele não exista
dir = 'Dados/RJ-SETOR/TEMP'
if not os.path.exists(dir):
    os.makedirs(dir)

# %% [raw]
# O método os.walk() :

# %% [markdown]
# <img src="walk.png" width=70%>

# %%
#Encontra o nome de todos os arquivos que estão na pasta 'files',em seguida descompacta em um diretório
filenames = []
for root, dirs, files in os.walk('Dados/RJ-SETOR/DADOS'):
    for name in files:
        zip_ref=zipfile.ZipFile('Dados/RJ-SETOR/DADOS/'+name,'r')
        zip_ref.extractall(dir)
        zip_ref.close()

# %% [markdown]
# ## Concatenando Shapefiles

# %%
#Abre o shape de todos os setores e concatena
setor=pd.concat([gpd.read_file(dir+'/'+item[:-4]+'_setor.shp') for item in files], ignore_index=True)
#Deleta a pasta temporária
shutil.rmtree(dir)

# %%
print(setor.crs)
#Configurando o sistema de coordenadas
setor=setor.to_crs('+proj=utm +zone=23 +south +ellps=GRS80 +towgs84=0,0,0,0,0,0,0 +units=km +no_defs')
print(setor.crs)
# Out:
# {'init': 'epsg:4674'}
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-eb305cfd94a3> in <module>
#       1 print(setor.crs)
#       2 #Configurando o sistema de coordenadas
# ----> 3 setor=setor.to_crs('+proj=utm +zone=23 +south +ellps=GRS80 +towgs84=0,0,0,0,0,0,0 +units=km +no_defs')
#       4 print(setor.crs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\geodataframe.py in to_crs(self, crs, epsg, inplace)
#     441         else:
#     442             df = self.copy()
# --> 443         geom = df.geometry.to_crs(crs=crs, epsg=epsg)
#     444         df.geometry = geom
#     445         df.crs = geom.crs
#
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\geoseries.py in to_crs(self, crs, epsg)
#     302             except TypeError:
#     303                 raise TypeError('Must set either crs or epsg for output.')
# --> 304         proj_in = pyproj.Proj(self.crs, preserve_units=True)
#     305         proj_out = pyproj.Proj(crs, preserve_units=True)
#     306         project = partial(pyproj.transform, proj_in, proj_out)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyproj\__init__.py in __new__(self, projparams, preserve_units, **kwargs)
#     360         # on case-insensitive filesystems).
#     361         projstring = projstring.replace('EPSG','epsg')
# --> 362         return _proj.Proj.__new__(self, projstring)
#     363
#     364     def __call__(self, *args, **kw):
#
# _proj.pyx in _proj.Proj.__cinit__()
#
# RuntimeError: b'no arguments in initialization list'

# %%
setor.plot()

# %% [markdown]
# ## Adicionando atributos ao shapefile

# %% [raw]
# Queremos adicionar dados do Censo de 2010 como atributos do shapefile de setores censitários.

# %%
censo=pd.read_excel('Dados/Censo 2010/RJ/EXCEL/Basico_RJ.xls')
censo.head()
# Out:
#          Cod_setor  Cod_Grandes Regiões Nome_Grande_Regiao Cod_UF  \
# 0  330010005000001                    3     Região Sudeste     RJ
# 1  330010005000002                    3     Região Sudeste     RJ
# 2  330010005000003                    3     Região Sudeste     RJ
# 3  330010005000004                    3     Região Sudeste     RJ
# 4  330010005000005                    3     Região Sudeste     RJ
#
#       Nome_da_UF   Cod_meso    Nome_da_meso  Cod_micro        Nome_da_micro  \
# 0  Rio de Janeiro      3305  Sul Fluminense      33013  Baía da Ilha Grande
# 1  Rio de Janeiro      3305  Sul Fluminense      33013  Baía da Ilha Grande
# 2  Rio de Janeiro      3305  Sul Fluminense      33013  Baía da Ilha Grande
# 3  Rio de Janeiro      3305  Sul Fluminense      33013  Baía da Ilha Grande
# 4  Rio de Janeiro      3305  Sul Fluminense      33013  Baía da Ilha Grande
#
#    Cod_RM     ...       V003  V004     V005         V006     V007  \
# 0       0     ...       2.62  1.94  2356.80   5716056.06  2571.06
# 1       0     ...       2.51  1.50  2040.47   3020377.79  2236.67
# 2       0     ...       3.08  2.19  2687.80   8362007.52  2836.66
# 3       0     ...       3.04  3.25  3026.67  24807309.86  3352.62
# 4       0     ...       3.34  1.94  1124.82    712447.24  1229.19
#
#           V008     V009         V010     V011         V012
# 0   5684616.94  1565.37   4344465.56  2192.65   4711305.89
# 1   2869054.77  1816.69  20052928.88  2375.67  24942113.99
# 2   8402987.99  1593.37   7250920.66  2294.84   8835722.10
# 3  26410753.99  1865.52  10994097.59  2574.41  13362652.63
# 4    649944.69   689.40    583588.50  1028.21    521878.03
#
# [5 rows x 33 columns]

# %%
setor.head()
# Out:
#       ID1       CD_GEOCODI    TIPO    CD_GEOCODB     NM_BAIRRO CD_GEOCODD  \
# 0  400341  330455705060018  URBANO  330455705004          Caju  330455705
# 1  400342  330455705060019  URBANO  330455705004          Caju  330455705
# 2  400343  330455705060020  URBANO  330455705004          Caju  330455705
# 3  400344  330455705060021  URBANO  330455705004          Caju  330455705
# 4  400347  330455705060024  URBANO  330455705003  Santo Cristo  330455705
#
#        NM_DISTRIT CD_GEOCODS NM_SUBDIST CD_GEOCODM      NM_MUNICIP  \
# 0  RIO DE JANEIRO  330455705  PORTUÁRIA    3304557  RIO DE JANEIRO
# 1  RIO DE JANEIRO  330455705  PORTUÁRIA    3304557  RIO DE JANEIRO
# 2  RIO DE JANEIRO  330455705  PORTUÁRIA    3304557  RIO DE JANEIRO
# 3  RIO DE JANEIRO  330455705  PORTUÁRIA    3304557  RIO DE JANEIRO
# 4  RIO DE JANEIRO  330455705  PORTUÁRIA    3304557  RIO DE JANEIRO
#
#                            NM_MESO        NM_MICRO  \
# 0  METROPOLITANA DO RIO DE JANEIRO  RIO DE JANEIRO
# 1  METROPOLITANA DO RIO DE JANEIRO  RIO DE JANEIRO
# 2  METROPOLITANA DO RIO DE JANEIRO  RIO DE JANEIRO
# 3  METROPOLITANA DO RIO DE JANEIRO  RIO DE JANEIRO
# 4  METROPOLITANA DO RIO DE JANEIRO  RIO DE JANEIRO
#
#                                             geometry
# 0  POLYGON ((683.349326221016 7469.17768684979, 6...
# 1  POLYGON ((683.3094976400794 7469.213659905473,...
# 2  POLYGON ((683.2982913807748 7469.418253547153,...
# 3  POLYGON ((683.4782944704702 7469.289246539755,...
# 4  POLYGON ((683.8518253829462 7465.621685850603,...

# %% [raw]
# A coluna Cod_setor do censo, e a coluna CD_GEOCODI do shapefile dos setores serão utilizadas como referência para concatenar os atributos, logo os valores nelas inseridos precisam ser do mesmo tipo.

# %%
censo.dtypes.head()
# Out:
# Cod_setor               int64
# Cod_Grandes Regiões     int64
# Nome_Grande_Regiao     object
# Cod_UF                 object
# Nome_da_UF             object
# dtype: object

# %%
setor.dtypes.head()
# Out:
# ID1            int64
# CD_GEOCODI    object
# TIPO          object
# CD_GEOCODB    object
# NM_BAIRRO     object
# dtype: object

# %% [raw]
# Como há divergência entre os tipos, temos que fazer a conversão.

# %%
censo['Cod_setor']=censo['Cod_setor'].astype(str)

# %%
censo.dtypes.head()
# Out:
# Cod_setor              object
# Cod_Grandes Regiões     int64
# Nome_Grande_Regiao     object
# Cod_UF                 object
# Nome_da_UF             object
# dtype: object

# %% [markdown]
# Utilizando a função pd.merge

# %% [markdown]
# <img src="merge.png" width=70%>

# %%
setor=pd.merge(setor,censo,left_on='CD_GEOCODI',right_on='Cod_setor',how='left')

# %%
setor.shape
# Out:
# (10504, 47)

# %%
setor.columns
# Out:
# Index(['ID1', 'CD_GEOCODI', 'TIPO', 'CD_GEOCODB', 'NM_BAIRRO', 'CD_GEOCODD',
#        'NM_DISTRIT', 'CD_GEOCODS', 'NM_SUBDIST', 'CD_GEOCODM', 'NM_MUNICIP',
#        'NM_MESO', 'NM_MICRO', 'geometry', 'Cod_setor', 'Cod_Grandes Regiões',
#        'Nome_Grande_Regiao', 'Cod_UF', 'Nome_da_UF ', 'Cod_meso',
#        'Nome_da_meso', 'Cod_micro', 'Nome_da_micro', 'Cod_RM', 'Nome_da_RM',
#        'Cod_municipio', 'Nome_do_municipio', 'Cod_distrito',
#        'Nome_do_distrito', 'Cod_subdistrito', 'Nome_do_subdistrito',
#        'Cod_bairro', 'Nome_do_bairro', 'Situacao_setor', 'Tipo_setor', 'V001',
#        'V002', 'V003', 'V004', 'V005', 'V006', 'V007', 'V008', 'V009', 'V010',
#        'V011', 'V012'],
#       dtype='object')

# %%
setor.crs
# Out:
# '+proj=utm +zone=23 +south +ellps=GRS80 +towgs84=0,0,0,0,0,0,0 +units=km +no_defs'

# %% [markdown]
# ## Juntando atributos de dois shapefiles

# %%
geo_dados=gpd.read_file('Dados/RJ-DATASET/DATASET.shp')

# %%
geo_dados.head()
# Out:
#    Area                    Bairro          Cidade  \
# 0   138  Recreio dos Bandeirantes  Rio de Janeiro
# 1   133   Freguesia (Jacarepaguá)  Rio de Janeiro
# 2    46                   Pilares  Rio de Janeiro
# 3    65           Barra da Tijuca  Rio de Janeiro
# 4   260  Recreio dos Bandeirantes  Rio de Janeiro
#
#                          Endereco Estado   Latitude  Longitude  Quartos  \
# 0             Rua Vicente Scofano     RJ -23.016455 -43.462946        3
# 1                   Rua Potiguara     RJ -22.943199 -43.336911        3
# 2   Rua Professor Carneiro Felipe     RJ -22.873849 -43.300517        1
# 3        Avenida Salvador Allende     RJ -22.984787 -43.412703        2
# 4  Rua Desembargador Paulo Alonso     RJ -23.018927 -43.477505        3
#
#    Suites  Vagas         Tipo Transacao    Valor  Dist_Metro  Dist_Trans  \
# 0       1      3  Apartamento     Venda  1095000   15.665002    0.443302
# 1       1      2  Apartamento     Venda   650000    7.494379    3.616386
# 2       0      0  Apartamento     Venda   150000    0.801969    0.668178
# 3       1      1  Apartamento     Venda   430000   10.743404    0.488183
# 4       1      2  Apartamento     Venda  1160000   17.173722    0.276796
#
#    Dist_Praia                                     geometry
# 0    1.103410  POINT (657.5137068691058 7453.832425203198)
# 1    7.422906  POINT (670.5239029320986 7461.803087641325)
# 2    6.303847  POINT (674.3450038415888 7469.439743130414)
# 3    3.357297  POINT (662.7013782087697 7457.284070512794)
# 4    1.318215  POINT (656.0187146395718 7453.574299351502)

# %%
print(setor.crs)
print(geo_dados.crs)
# Out:
# +proj=utm +zone=23 +south +ellps=GRS80 +towgs84=0,0,0,0,0,0,0 +units=km +no_defs
# {'proj': 'utm', 'zone': 23, 'south': True, 'ellps': 'GRS80', 'units': 'km', 'no_defs': True}

# %%
base=setor.plot(color='white',edgecolor='gray',figsize=(15,8))
geo_dados.plot(ax=base,color='blue',markersize=1)

# %% [raw]
# Nesse caso, os atributos dos setores censitários serão adicionados ao shape dos imóveis (pontos), onde os imóveis irão absorver os dados dos setores censitários em que estão inseridos.
# Em alguns casos, o ponto do imóvel pode estar na fronteira entre dois setores, então o ponto será duplicado..

# %%
geo_dados=gpd.sjoin(geo_dados,setor,how='left',op='within')
# Out:
# Warning: CRS does not match!

# %%
geo_dados.shape
# Out:
# (4516, 64)

# %%
geo_dados=geo_dados[~geo_dados.index.duplicated(keep='first')] #Mantém o primeiro
geo_dados.shape
# Out:
# (4513, 64)

# %%
geo_dados.crs
# Out:
# {'proj': 'utm',
#  'zone': 23,
#  'south': True,
#  'ellps': 'GRS80',
#  'units': 'km',
#  'no_defs': True}

# %%
geo_dados.to_file('Dados/RJ-DATASET/DATASET.shp')
# Out:
# C:\Users\walli\Anaconda3\lib\site-packages\geopandas\io\file.py:62: FionaDeprecationWarning: Use fiona.Env() instead.
#   with fiona.drivers():
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf5 in position 50: invalid start byte
# Exception ignored in: 'fiona._env.log_error'
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf5 in position 50: invalid start byte

# %% [markdown]
# ## Agregando regiões geográficas

# %%
setor.plot(color='white',edgecolor='black',figsize=(15,8))

# %%
# Para usar o método dissolve, o sistemas de coordenadas tem que ser geográficas, e não projetadas
setor=setor.to_crs({'init':'epsg:4326'})
setor_m=setor[['NM_BAIRRO','geometry','V002']]

# %%
setor_m.plot()

# %%
#Dissolve os setores censitários por bairros e faz a soma dos valores de cada setor para o bairro.
bairro=setor_m.dissolve(by='NM_BAIRRO',aggfun='sum') 
bairro.plot()
# Out:
# TopologyException: Input geom 0 is invalid: Self-intersection at or near point -43.250213293714594 -22.887739582871898 at -43.250213293714594 -22.887739582871898
# TopologyException: Input geom 0 is invalid: Self-intersection at or near point -43.250213293714594 -22.887739582871898 at -43.250213293714594 -22.887739582871898
# TopologyException: Input geom 0 is invalid: Self-intersection at or near point -43.250213293714594 -22.887739582871898 at -43.250213293714594 -22.887739582871898
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in agg_series(self, obj, func)
#     589         try:
# --> 590             return self._aggregate_series_fast(obj, func)
#     591         except Exception:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in _aggregate_series_fast(self, obj, func)
#     609                                           dummy)
# --> 610         result, counts = grouper.get_result()
#     611         return result, counts
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in <lambda>(x)
#     843         func = self._is_builtin_func(func)
# --> 844         f = lambda x: func(x, *args, **kwargs)
#     845
#
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\geodataframe.py in merge_geometries(block)
#     569         def merge_geometries(block):
# --> 570             merged_geom = block.unary_union
#     571             return merged_geom
#
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\base.py in unary_union(self)
#     235         ``GeoSeries``."""
# --> 236         return unary_union(self.geometry.values)
#     237
#
# C:\ProgramData\Anaconda3\lib\site-packages\shapely\ops.py in unary_union(self, geoms)
#     148         collection = lgeos.GEOSGeom_createCollection(6, subs, L)
# --> 149         return geom_factory(lgeos.methods['unary_union'](collection))
#     150
#
# C:\ProgramData\Anaconda3\lib\site-packages\shapely\geometry\base.py in geom_factory(g, parent)
#      75     if not g:
# ---> 76         raise ValueError("No Shapely geometry can be created from null value")
#      77     ob = BaseGeometry()
#
# ValueError: No Shapely geometry can be created from null value
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     775             try:
# --> 776                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#     777             except Exception:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_agg_general(self, func, *args, **kwargs)
#     849             try:
# --> 850                 result, counts = self.grouper.agg_series(obj, f)
#     851                 output[name] = self._try_cast(result, obj, numeric_only=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in agg_series(self, obj, func)
#     591         except Exception:
# --> 592             return self._aggregate_series_pure_python(obj, func)
#     593
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in _aggregate_series_pure_python(self, obj, func)
#     622         for label, group in splitter:
# --> 623             res = func(group)
#     624             if result is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in <lambda>(x)
#     843         func = self._is_builtin_func(func)
# --> 844         f = lambda x: func(x, *args, **kwargs)
#     845
#
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\geodataframe.py in merge_geometries(block)
#     569         def merge_geometries(block):
# --> 570             merged_geom = block.unary_union
#     571             return merged_geom
#
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\base.py in unary_union(self)
#     235         ``GeoSeries``."""
# --> 236         return unary_union(self.geometry.values)
#     237
#
# C:\ProgramData\Anaconda3\lib\site-packages\shapely\ops.py in unary_union(self, geoms)
#     148         collection = lgeos.GEOSGeom_createCollection(6, subs, L)
# --> 149         return geom_factory(lgeos.methods['unary_union'](collection))
#     150
#
# C:\ProgramData\Anaconda3\lib\site-packages\shapely\geometry\base.py in geom_factory(g, parent)
#      75     if not g:
# ---> 76         raise ValueError("No Shapely geometry can be created from null value")
#      77     ob = BaseGeometry()
#
# ValueError: No Shapely geometry can be created from null value
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-0c6a1d82f0ca> in <module>
# ----> 1 setor_m.dissolve(by='NM_BAIRRO')
#       2 setor_m.plot()
#
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\geodataframe.py in dissolve(self, by, aggfunc, as_index)
#     571             return merged_geom
#     572
# --> 573         g = self.groupby(by=by, group_keys=False)[self.geometry.name].agg(merge_geometries)
#     574
#     575         # Aggregate
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     776                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#     777             except Exception:
# --> 778                 result = self._aggregate_named(func_or_funcs, *args, **kwargs)
#     779
#     780             index = Index(sorted(result), name=self.grouper.names[0])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _aggregate_named(self, func, *args, **kwargs)
#     905         for name, group in self:
#     906             group.name = name
# --> 907             output = func(group, *args, **kwargs)
#     908             if isinstance(output, (Series, Index, np.ndarray)):
#     909                 raise Exception('Must produce aggregated value')
#
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\geodataframe.py in merge_geometries(block)
#     568         # Process spatial component
#     569         def merge_geometries(block):
# --> 570             merged_geom = block.unary_union
#     571             return merged_geom
#     572
#
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\base.py in unary_union(self)
#     234         """Returns a geometry containing the union of all geometries in the
#     235         ``GeoSeries``."""
# --> 236         return unary_union(self.geometry.values)
#     237
#     238     #
#
# C:\ProgramData\Anaconda3\lib\site-packages\shapely\ops.py in unary_union(self, geoms)
#     147             subs[i] = g._geom
#     148         collection = lgeos.GEOSGeom_createCollection(6, subs, L)
# --> 149         return geom_factory(lgeos.methods['unary_union'](collection))
#     150
#     151 operator = CollectionOperator()
#
# C:\ProgramData\Anaconda3\lib\site-packages\shapely\geometry\base.py in geom_factory(g, parent)
#      74     # Abstract geometry factory for use with topological methods below
#      75     if not g:
# ---> 76         raise ValueError("No Shapely geometry can be created from null value")
#      77     ob = BaseGeometry()
#      78     geom_type = geometry_type_name(g)
#
# ValueError: No Shapely geometry can be created from null value
